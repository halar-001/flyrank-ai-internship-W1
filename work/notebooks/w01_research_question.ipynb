# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/halar-001/flyrank-ai-internship-W1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### **My Lane**
#
# I chose the **Content Optimization** lane because improving the visibility of existing pages is an important and practical SEO task. My goal is to identify pages that are likely to experience declining organic performance so they can be reviewed and updated before they lose significant traffic. This problem combines measurable search metrics with actionable recommendations, making it a suitable machine learning problem.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Research Question:** Which pages are most likely to experience declining organic search performance in the near future?
#
# **Decision:** Determine which pages should be prioritized for content updates.
#
# **Action:** SEO specialists or content managers can review and refresh the identified pages.
#
# **Cost of a Wrong Recommendation:** If declining pages are missed, valuable organic traffic may continue to decrease. If stable pages are incorrectly flagged, time and resources may be spent updating content that does not require attention.
#
# **Why Machine Learning:** Multiple factors such as impressions, CTR, average position, content age, and update history may interact in ways that are difficult to capture with simple manual rules. Machine learning can combine these signals to provide better decision support.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ##Quick Look at the Data
# The starter dataset contains 3000 pages. The average CTR is 0.511, and 16.34% of the pages are labelled as declining. These observations suggest that there is meaningful variation in page performance, making this a useful problem to investigate further over the internship.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

df = pd.read_csv("content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Average Position:", round(df["avg_position"].mean(), 2))
print("\nContent Types:")
print(df["content_type"].value_counts())
print("\nTrend Direction:")
print(df["trend_direction"].value_counts())
# Out:
# Total pages: 30000
# Average CTR: 0.511
# Average Position: 16.34
#
# Content Types:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64
#
# Trend Direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Language
#
# This project will identify observed patterns and directional relationships in historical search data. The model is intended to support human decision-making by highlighting pages that may deserve further attention.
#
# The project will not prove causal relationships, explain how Google's ranking algorithm works, or guarantee future ranking changes. Any recommendations should be treated as decision support rather than definitive predictions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
